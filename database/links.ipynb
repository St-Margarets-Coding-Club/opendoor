# %%
# To access the database
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://<dbusername>:<dbpassword>@cluster0.13icold.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# Access the database
db = client['animalsdb']

# %%
# Access the collection
collection = db['animals']

# %%
# To get every field that contains a link from every document in the collection
links = collection.find({}, {"_id": 0, "link": 1})

with open('links.txt', 'w', encoding='utf-8') as f:
    for doc in links:
        link = doc.get('link', '')
        f.write(link + '\n')

print("Links have been written to links.txt")
# Out:
# Links have been written to links.txt
