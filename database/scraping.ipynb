# %%
# Iterate through each line in
with open('batch.txt', 'r', encoding='utf-8') as file:
    links = file.readlines()

# %%
pip install requests beautifulsoup4

# %%
# Fetch the HTML content of each link
import requests
from bs4 import BeautifulSoup

# %%
class ImageScraper:
    def fetch(self, url):
        return requests.get(url)
    def parse(self, html):
        print(html)
    def download(self, url):
        pass
    def run(self):
        response = self.fetch(links[0].strip())
        self.parse(response.text)

# %%
if __name__ == "__main__":
    scraper = ImageScraper()
    scraper.run()
# Out:
# <Response [403]>

# %%
# Scraping doesn't work, you must cleanse the data manually and insert the images source links into the Cloudinary with Python and insert them into your database with PyMongo
