# %%
pip install pymongo

# %%
# To access the database
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://<db_username>:<db_password>@cluster0.13icold.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
pip install pandas

# %%
# Load the dataset
import pandas as pd

df = pd.read_csv('animals.csv')
df.head()
# Out:
#               organization    type gender       name  \
# 0  Hong Kong Rabit Society  Rabbit      F       Vico
# 1     Hong Kong Dog Rescue     Dog      F     Gladys
# 2                     SPCA     Dog      M         浩浩
# 3      Paws United Charity     Dog      F  Bridgette
# 4                   HKSCDA     Cat      F      Donki
#
#                               link Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0  https://siuyeo.ng/hkaad20251225        NaN        NaN        NaN
# 1  https://siuyeo.ng/hkaad20251224        NaN        NaN        NaN
# 2  https://siuyeo.ng/hkaad20251223        NaN        NaN        NaN
# 3  https://siuyeo.ng/hkaad20251222        NaN        NaN        NaN
# 4  https://siuyeo.ng/hkaad20251221        NaN        NaN        NaN

# %%
# Deal with missing values
type(df['Unnamed: 5'].loc[0])
# Out:
# float

# %%
df = df.astype(object).where(pd.notna(df), None)

# %%
df.head()
# Out:
#               organization    type gender       name  \
# 0  Hong Kong Rabit Society  Rabbit      F       Vico
# 1     Hong Kong Dog Rescue     Dog      F     Gladys
# 2                     SPCA     Dog      M         浩浩
# 3      Paws United Charity     Dog      F  Bridgette
# 4                   HKSCDA     Cat      F      Donki
#
#                               link Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0  https://siuyeo.ng/hkaad20251225       None       None       None
# 1  https://siuyeo.ng/hkaad20251224       None       None       None
# 2  https://siuyeo.ng/hkaad20251223       None       None       None
# 3  https://siuyeo.ng/hkaad20251222       None       None       None
# 4  https://siuyeo.ng/hkaad20251221       None       None       None

# %%
list_of_dicts = df.to_dict(orient='records')

# %%
list_of_dicts
# Out:
# [{'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Vico',
#   'link': 'https://siuyeo.ng/hkaad20251225',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Gladys',
#   'link': 'https://siuyeo.ng/hkaad20251224',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': '浩浩',
#   'link': 'https://siuyeo.ng/hkaad20251223',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Bridgette',
#   'link': 'https://siuyeo.ng/hkaad20251222',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Donki',
#   'link': 'https://siuyeo.ng/hkaad20251221',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Saturday',
#   'link': 'https://siuyeo.ng/hkaad20251220',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Lulu',
#   'link': 'https://siuyeo.ng/hkaad20251219',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Turtle',
#   'gender': None,
#   'name': '紅豆',
#   'link': 'https://siuyeo.ng/hkaad20251218',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Zespri',
#   'link': 'https://siuyeo.ng/hkaad20251217',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Wolfie',
#   'link': 'https://siuyeo.ng/hkaad20251216',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Sailor',
#   'link': 'https://siuyeo.ng/hkadd20251215',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Letty',
#   'link': 'https://siuyeo.ng/hkaad20251214',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '錦小龍',
#   'link': 'https://siuyeo.ng/hkaad20251213',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Wednesday',
#   'link': 'https://siuyeo.ng/hkaad20251212',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Mimi',
#   'link': 'https://siuyeo.ng/hkaad20251211',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Snake',
#   'gender': None,
#   'name': 'AC08',
#   'link': 'https://siuyeo.ng/hkaad20251210',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Mofu',
#   'link': 'https://siuyeo.ng/hkaad20251209',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Gallant',
#   'link': 'https://siuyeo.ng/hkaad20251208',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': 'Wavey',
#   'link': 'https://siuyeo.ng/hkaad20251207',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Holly',
#   'link': 'https://siuyeo.ng/hkaad20251206',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'WINWIN',
#   'link': 'https://siuyeo.ng/hkadd20251205',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Monday',
#   'link': 'https://siuyeo.ng/hkaad20251204',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '亞黃',
#   'link': 'https://siuyeo.ng/hkaad20251203',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Frog',
#   'gender': None,
#   'name': '蛋黃妹',
#   'link': 'https://siuyeo.ng/hkaad20251202',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'M',
#   'name': 'Reo',
#   'link': 'https://siuyeo.ng/hkaad20251201',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Justin',
#   'link': 'https://siuyeo.ng/hkaad20251130',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Charlotte',
#   'link': 'https://siuyeo.ng/hkaad20251129',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Aaron',
#   'link': 'https://siuyeo.ng/hkaad20251128',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '周生生',
#   'link': 'https://siuyeo.ng/hkaad20251127',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Sugar',
#   'link': 'https://siuyeo.ng/hkaad20251126',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Billy',
#   'link': 'https://siuyeo.ng/hkaad20251125',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Snake',
#   'gender': None,
#   'name': '阿橙',
#   'link': 'https://siuyeo.ng/hkaad20251124',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Lana',
#   'link': 'https://siuyeo.ng/hkaad20251123',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Simone',
#   'link': 'https://siuyeo.ng/hkaad20251122',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': '貝貝',
#   'link': 'https://siuyeo.ng/hkaad20251121',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Bridgette',
#   'link': 'https://siuyeo.ng/hkaad20251120',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '金三妹',
#   'link': 'https://siuyeo.ng/hkaad20251119',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Doddie',
#   'link': 'https://siuyeo.ng/hkaad20251118',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '喱喱',
#   'link': 'https://siuyeo.ng/hkaad20251117',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Turtle',
#   'gender': None,
#   'name': '紅豆',
#   'link': 'https://siuyeo.ng/hkaad20251116',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Koaki',
#   'link': 'https://siuyeo.ng/hkaad20251115',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Nino',
#   'link': 'https://siuyeo.ng/hkaad20251114',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Mia',
#   'link': 'https://siuyeo.ng/hkaad20251113',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Rachel',
#   'link': 'https://siuyeo.ng/hkaad20251112',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '金大妹',
#   'link': 'https://siuyeo.ng/hkaad20251111',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Cody',
#   'link': 'https://siuyeo.ng/hkaad20251110',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '亞蝦',
#   'link': 'https://siuyeo.ng/hkaad20251109',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Frog',
#   'gender': None,
#   'name': '蛋黃妹',
#   'link': 'https://siuyeo.ng/hkaad20251108',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Joni',
#   'link': 'https://siuyeo.ng/hkaad20251107',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Todd',
#   'link': 'https://siuyeo.ng/hkaad20251106',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '峰峰',
#   'link': 'https://siuyeo.ng/hkaad20251105',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Kylie',
#   'link': 'https://siuyeo.ng/hkaad20251104',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '樂樂',
#   'link': 'https://siuyeo.ng/hkaad20251103',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Wasabi',
#   'link': 'https://siuyeo.ng/hkaad20251102',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': '香蕉',
#   'link': 'https://siuyeo.ng/hkaad20251101',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Snake',
#   'gender': None,
#   'name': '阿橙',
#   'link': 'https://siuyeo.ng/hkaad20251031',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Yama',
#   'link': 'https://siuyeo.ng/hkaad20251030',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Mercury',
#   'link': 'https://siuyeo.ng/hkaad20251029',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Spongebob',
#   'link': 'https://siuyeo.ng/hkaad20251028',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Sienna',
#   'link': 'https://siuyeo.ng/hkaad20251027',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '古心怡',
#   'link': 'https://siuyeo.ng/hkaad20251026',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Yan Yan',
#   'link': 'https://siuyeo.ng/hkaad20251025',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': '乖乖',
#   'link': 'https://siuyeo.ng/hkaad20251024',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Turtle',
#   'gender': None,
#   'name': '紅豆',
#   'link': 'https://siuyeo.ng/hkaad20251023',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Ciwi',
#   'link': 'https://siuyeo.ng/hkaad20251022',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Tumble',
#   'link': 'https://siuyeo.ng/hkaad20251021',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Moana',
#   'link': 'https://siuyeo.ng/hkaad20251020',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Bridgette',
#   'link': 'https://siuyeo.ng/hkaad20251019',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '細佬',
#   'link': 'https://siuyeo.ng/hkaad20251018',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Mei Mei',
#   'link': 'https://siuyeo.ng/hkaad20251017',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': 'Winson',
#   'link': 'https://siuyeo.ng/hkaad20251016',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Frog',
#   'gender': None,
#   'name': '蛋黃妹',
#   'link': 'https://siuyeo.ng/hkaad20251015',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'M',
#   'name': 'Vegas',
#   'link': 'https://siuyeo.ng/hkaad20251014',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Erin',
#   'link': 'https://siuyeo.ng/hkaad20251013',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': '小邁',
#   'link': 'https://siuyeo.ng/hkaad20251012',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Swan',
#   'link': 'https://siuyeo.ng/hkaad20251011',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '水飯飯',
#   'link': 'https://siuyeo.ng/hkaad20251010',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Z',
#   'link': 'https://siuyeo.ng/hkaad20251009',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': '叻仔',
#   'link': 'https://siuyeo.ng/hkaad20251008',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Snake',
#   'gender': None,
#   'name': '阿橙',
#   'link': 'https://siuyeo.ng/hkaad20251007',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'M',
#   'name': 'Gin',
#   'link': 'https://siuyeo.ng/hkaad20251006',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Unity',
#   'link': 'https://siuyeo.ng/hkaad20251005',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': '琑琑',
#   'link': 'https://siuyeo.ng/hkaad20251004',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Bose',
#   'link': 'https://siuyeo.ng/hkaad20251003',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '美細妹',
#   'link': 'https://siuyeo.ng/hkaad20251002',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': 'Tab',
#   'link': 'https://siuyeo.ng/hkaad20251001',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Windsor',
#   'link': 'https://siuyeo.ng/hkaad20250930',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Turtle',
#   'gender': None,
#   'name': '紅豆',
#   'link': 'https://siuyeo.ng/hkaad20250929',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Gulu',
#   'link': 'https://siuyeo.ng/hkaad20250928',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Viva',
#   'link': 'https://siuyeo.ng/hkaad20250927',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Dorma',
#   'link': 'https://siuyeo.ng/hkaad20250926',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'George',
#   'link': 'https://siuyeo.ng/hkaad20250925',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '美家姐',
#   'link': 'https://siuyeo.ng/hkaad20250924',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': 'Gin',
#   'link': 'https://siuyeo.ng/hkaad20250923',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Bear Bear',
#   'link': 'https://siuyeo.ng/hkaad20250922',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Frog',
#   'gender': None,
#   'name': '蛋黃妹',
#   'link': 'https://siuyeo.ng/hkaad20250921',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'M',
#   'name': 'Goma',
#   'link': 'https://siuyeo.ng/hkaad20250920',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Theo',
#   'link': 'https://siuyeo.ng/hkaad20250919',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': '樂諾',
#   'link': 'https://siuyeo.ng/hkaad20250918',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Sammy',
#   'link': 'https://siuyeo.ng/hkaad20250917',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '王梅子',
#   'link': 'https://siuyeo.ng/hkaad20250916',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Dit Dit',
#   'link': 'https://siuyeo.ng/hkaad20250915',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '喱喱',
#   'link': 'https://siuyeo.ng/hkaad20250914',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Turtle',
#   'gender': None,
#   'name': '阿聰',
#   'link': 'https://siuyeo.ng/hkaad20250913',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Lilo',
#   'link': 'https://siuyeo.ng/hkaad20250912',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Kira',
#   'link': 'https://siuyeo.ng/hkaad20250911',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Truffle',
#   'link': 'https://siuyeo.ng/hkaad20250910',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Sandra',
#   'link': 'https://siuyeo.ng/hkaad20250909',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '靜靜',
#   'link': 'https://siuyeo.ng/hkaad20250908',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': 'DuDu',
#   'link': 'https://siuyeo.ng/hkaad20250907',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '黑芝麻',
#   'link': 'https://siuyeo.ng/hkaad20250906',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Lizard',
#   'gender': 'M',
#   'name': 'Crown',
#   'link': 'https://siuyeo.ng/hkaad20250905',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Mugi',
#   'link': 'https://siuyeo.ng/hkaad20250904',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Wiggy',
#   'link': 'https://siuyeo.ng/hkaad20250903',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Choco',
#   'link': 'https://siuyeo.ng/hkaad20250902',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Sonos',
#   'link': 'https://siuyeo.ng/hkaad20250901',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '埔娃娃',
#   'link': 'https://siuyeo.ng/hkaad20250831',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '嘉嘉',
#   'link': 'https://siuyeo.ng/hkaad20250830',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '安安',
#   'link': 'https://siuyeo.ng/hkaad20250829',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Snake',
#   'gender': None,
#   'name': '阿橙',
#   'link': 'https://siuyeo.ng/hkaad20250828',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Bokki',
#   'link': 'https://siuyeo.ng/hkaad20250827',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Ziggy',
#   'link': 'https://siuyeo.ng/hkaad20250826',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Solar',
#   'link': 'https://siuyeo.ng/hkaad20250825',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Almond',
#   'link': 'https://siuyeo.ng/hkaad20250824',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '囝囝',
#   'link': 'https://siuyeo.ng/hkaad20250823',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '松松',
#   'link': 'https://siuyeo.ng/hkaad20250822',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Billy',
#   'link': 'https://siuyeo.ng/hkaad20250821',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Turtle',
#   'gender': None,
#   'name': '阿聰',
#   'link': 'https://siuyeo.ng/hkaad20250820',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Mercury',
#   'link': 'https://siuyeo.ng/hkaad20250819',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Tinker',
#   'link': 'https://siuyeo.ng/hkaad20250818',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Minions',
#   'link': 'https://siuyeo.ng/hkaad20250817',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Holly',
#   'link': 'https://siuyeo.ng/hkaad20250816',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '雪碧',
#   'link': 'https://siuyeo.ng/hkaad20250815',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '露露',
#   'link': 'https://siuyeo.ng/hkaad20250814',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': '豬仔',
#   'link': 'https://siuyeo.ng/hkaad20250813',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Frog',
#   'gender': None,
#   'name': '蛋黃妹',
#   'link': 'https://siuyeo.ng/hkaad20250812',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'M',
#   'name': 'Slinky',
#   'link': 'https://siuyeo.ng/hkaad20250811',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Omega',
#   'link': 'https://siuyeo.ng/hkaad20250810',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Don Don',
#   'link': 'https://siuyeo.ng/hkaad20250809',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Frank',
#   'link': 'https://siuyeo.ng/hkaad20250808',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '芬達',
#   'link': 'https://siuyeo.ng/hkaad20250807',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Puffie',
#   'link': 'https://siuyeo.ng/hkaad20250806',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '仔仔',
#   'link': 'https://siuyeo.ng/hkaad20250805',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Turtle',
#   'gender': None,
#   'name': '紅豆',
#   'link': 'https://siuyeo.ng/hkaad20250804',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Woody',
#   'link': 'https://siuyeo.ng/hkaad20250803',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Oscar',
#   'link': 'https://siuyeo.ng/hkaad20250802',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '黑黑',
#   'link': 'https://siuyeo.ng/hkaad20250801',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': 'Lodi',
#   'link': 'https://siuyeo.ng/hkaad20250731',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '大腳板',
#   'link': 'https://siuyeo.ng/hkaad20250730',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': 'Bill Bill',
#   'link': 'https://siuyeo.ng/hkaad20250729',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Renee',
#   'link': 'https://siuyeo.ng/hkaad20250728',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Snake',
#   'gender': None,
#   'name': '阿橙',
#   'link': 'https://siuyeo.ng/hkaad20250727',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Bubbly',
#   'link': 'https://siuyeo.ng/hkaad20250726',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Coral',
#   'link': 'https://siuyeo.ng/hkaad20250725',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'James',
#   'link': 'https://siuyeo.ng/hkaad20250724',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Maisy',
#   'link': 'https://siuyeo.ng/hkaad20250723',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': 'Soriano',
#   'link': 'https://siuyeo.ng/hkaad20250722',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Luna',
#   'link': 'https://siuyeo.ng/hkaad20250721',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': 'Romeo',
#   'link': 'https://siuyeo.ng/hkaad20250720',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Frog',
#   'gender': None,
#   'name': '蛋黃妹',
#   'link': 'https://siuyeo.ng/hkaad20250719',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Brulee',
#   'link': 'https://siuyeo.ng/hkaad20250718',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Carter',
#   'link': 'https://siuyeo.ng/hkaad20250717',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': '鼻鼻',
#   'link': 'https://siuyeo.ng/hkaad20250716',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': 'Bobbie',
#   'link': 'https://siuyeo.ng/hkaad20250715',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': 'Leon',
#   'link': 'https://siuyeo.ng/hkaad20250714',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': 'Sol',
#   'link': 'https://siuyeo.ng/hkaad20250713',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '辣椒妹',
#   'link': 'https://siuyeo.ng/hkaad20250712',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Turtle',
#   'gender': None,
#   'name': '紅豆',
#   'link': 'https://siuyeo.ng/hkaad20250711',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Qoo',
#   'link': 'https://siuyeo.ng/hkaad20250710',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Jimmy',
#   'link': 'https://siuyeo.ng/hkaad20250709',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Gigi',
#   'link': 'https://siuyeo.ng/hkaad20250708',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Meko',
#   'link': 'https://siuyeo.ng/hkaad20250707',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '嘟嘟',
#   'link': 'https://siuyeo.ng/hkaad20250706',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '水水',
#   'link': 'https://siuyeo.ng/hkaad20250705',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Mimi',
#   'link': 'https://siuyeo.ng/hkaad20250704',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Snake',
#   'gender': None,
#   'name': '阿橙',
#   'link': 'https://siuyeo.ng/hkaad20250703',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Monki',
#   'link': 'https://siuyeo.ng/hkaad20250702',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Roman',
#   'link': 'https://siuyeo.ng/hkaad20250701',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '點點',
#   'link': 'https://siuyeo.ng/hkaad20250630',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Fiat',
#   'link': 'https://siuyeo.ng/hkaad20250629',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': 'Cello',
#   'link': 'https://siuyeo.ng/hkaad20250628',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '小花',
#   'link': 'https://siuyeo.ng/hkaad20250627',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': '吉仔',
#   'link': 'https://siuyeo.ng/hkaad20250626',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Snake',
#   'gender': None,
#   'name': 'Higos',
#   'link': 'https://siuyeo.ng/hkaad20250625',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Gloria',
#   'link': 'https://siuyeo.ng/hkaad20250624',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Sabrina',
#   'link': 'https://siuyeo.ng/hkaad20250623',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': '芝麻',
#   'link': 'https://siuyeo.ng/hkaad20250622',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Pewter',
#   'link': 'https://siuyeo.ng/hkaad20250621',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '晨光',
#   'link': 'https://siuyeo.ng/hkaad20250620',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': 'Panther',
#   'link': 'https://siuyeo.ng/hkaad20250619',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Lucy',
#   'link': 'https://siuyeo.ng/hkaad20250618',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Frog',
#   'gender': None,
#   'name': '蛋黃妹',
#   'link': 'https://siuyeo.ng/hkaad20250617',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Jippi',
#   'link': 'https://siuyeo.ng/hkaad20250616',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Josh',
#   'link': 'https://siuyeo.ng/hkaad20250615',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '細細',
#   'link': 'https://siuyeo.ng/hkaad20250614',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'George',
#   'link': 'https://siuyeo.ng/hkaad20250613',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '叮噹',
#   'link': 'https://siuyeo.ng/hkaad20250612',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '安安',
#   'link': 'https://siuyeo.ng/hkaad20250611',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '亞黃',
#   'link': 'https://siuyeo.ng/hkaad20250610',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Lizard',
#   'gender': None,
#   'name': 'Martini',
#   'link': 'https://siuyeo.ng/hkaad20250609',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'M',
#   'name': 'Solstice',
#   'link': 'https://siuyeo.ng/hkaad20250608',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Piggy',
#   'link': 'https://siuyeo.ng/hkaad20250607',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': '烏龍',
#   'link': 'https://siuyeo.ng/hkaad20250606',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Berry',
#   'link': 'https://siuyeo.ng/hkaad20250605',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '山旮旯',
#   'link': 'https://siuyeo.ng/hkaad20250604',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': 'Cooper',
#   'link': 'https://siuyeo.ng/hkaad20250603',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': '朱事丁妹妹',
#   'link': 'https://siuyeo.ng/hkaad20250602',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Snake',
#   'gender': None,
#   'name': '蟒友',
#   'link': 'https://siuyeo.ng/hkaad20250601',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Oggy',
#   'link': 'https://siuyeo.ng/hkaad20250531',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Duke',
#   'link': 'https://siuyeo.ng/hkaad20250530',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Nash',
#   'link': 'https://siuyeo.ng/hkaad20250529',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Mindy',
#   'link': 'https://siuyeo.ng/hkaad20250528',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'KellyB',
#   'link': 'https://siuyeo.ng/hkaad20250527',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'La La',
#   'link': 'https://siuyeo.ng/hkaad20250526',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': '勝勝',
#   'link': 'https://siuyeo.ng/hkaad20250525',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Snake',
#   'gender': None,
#   'name': '迷蟒',
#   'link': 'https://siuyeo.ng/hkaad20250524',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'M',
#   'name': 'Smokey',
#   'link': 'https://siuyeo.ng/hkaad20250523',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Phoenix',
#   'link': 'https://siuyeo.ng/hkaad20250522',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': '灘仔',
#   'link': 'https://siuyeo.ng/hkaad20250521',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Wooly',
#   'link': 'https://siuyeo.ng/hkaad20250520',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '荃森森',
#   'link': 'https://siuyeo.ng/hkaad20250519',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '妮妮',
#   'link': 'https://siuyeo.ng/hkaad20250518',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Lulu',
#   'link': 'https://siuyeo.ng/hkaad20250517',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Snake',
#   'gender': None,
#   'name': '蟒掂',
#   'link': 'https://siuyeo.ng/hkaad20250516',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'M',
#   'name': 'Arroyo',
#   'link': 'https://siuyeo.ng/hkaad20250515',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Ike',
#   'link': 'https://siuyeo.ng/hkaad20250514',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Kammi',
#   'link': 'https://siuyeo.ng/hkaad20250513',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Almond',
#   'link': 'https://siuyeo.ng/hkaad20250512',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '荃圍圍',
#   'link': 'https://siuyeo.ng/hkaad20250511',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '多多',
#   'link': 'https://siuyeo.ng/hkaad20250510',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '小瑩瑩',
#   'link': 'https://siuyeo.ng/hkaad20250509',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Snake',
#   'gender': None,
#   'name': '余仁生',
#   'link': 'https://siuyeo.ng/hkaad20250508',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Melty',
#   'link': 'https://siuyeo.ng/hkaad20250507',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Plum',
#   'link': 'https://siuyeo.ng/hkaad20250506',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': '龍仔',
#   'link': 'https://siuyeo.ng/hkaad20250505',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Sandra',
#   'link': 'https://siuyeo.ng/hkaad20250504',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '埔埔豬',
#   'link': 'https://siuyeo.ng/hkaad20250503',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '阿V',
#   'link': 'https://siuyeo.ng/hkaad20250502',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '金比',
#   'link': 'https://siuyeo.ng/hkaad20250501',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Turtle',
#   'gender': 'M',
#   'name': '寶寶',
#   'link': 'https://siuyeo.ng/hkaad20250430',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'M',
#   'name': 'Vodka',
#   'link': 'https://siuyeo.ng/hkaad20250429',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Misty',
#   'link': 'https://siuyeo.ng/hkaad20250428',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Bambi',
#   'link': 'https://siuyeo.ng/hkaad20250427',
# ...
#  {'organization': 'Paws United Charity',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': 'Palmer',
#   'link': 'https://t.ly/wsmB',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '英姿',
#   'link': 'https://t.ly/HV0ks',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Lo Lo',
#   'link': 'https://t.ly/_9lnk',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': '愛瑪',
#   'link': 'https://t.ly/lgfe',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Turtle',
#   'gender': None,
#   'name': '阿望',
#   'link': 'https://t.ly/a6eK',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'M',
#   'name': 'Goma',
#   'link': 'https://t.ly/-iwU',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Jiffy',
#   'link': 'https://is.gd/P0IcmW',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Hyena',
#   'link': 'https://is.gd/TawTB0',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Cherie',
#   'link': 'https://t.ly/Tepm',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '滿島山',
#   'link': 'https://t.ly/wCjP',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Apple',
#   'link': 'https://is.gd/HAWvVD',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': '肥妹',
#   'link': 'https://t.ly/-_5H',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Snake',
#   'gender': None,
#   'name': '乳牛',
#   'link': 'https://t.ly/CpvQ',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'M',
#   'name': 'Long Long',
#   'link': 'https://t.ly/OFsF',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Cino',
#   'link': 'https://t.ly/VZyP',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Chocolate',
#   'link': 'https://t.ly/YUTm',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Vania',
#   'link': 'https://t.ly/Qqpz',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '綠茶',
#   'link': 'https://t.ly/G_Wu',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': '虎紋',
#   'link': 'https://t.ly/7w1b',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': '比比',
#   'link': 'https://t.ly/MjpN',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Turtle',
#   'gender': None,
#   'name': '阿細',
#   'link': 'https://t.ly/fXl1',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Lilo',
#   'link': 'https://t.ly/yDFvm',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Pokkie',
#   'link': 'https://t.ly/A3uL',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Puff',
#   'link': 'https://t.ly/uyjm',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Kyoho',
#   'link': 'https://t.ly/gQiX',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '小精靈',
#   'link': 'https://siuyeo.ng/7wvte',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': '阿嬌',
#   'link': 'https://siuyeo.ng/ewc4p',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Dicky',
#   'link': 'https://siuyeo.ng/Ewc18',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Turtle',
#   'gender': None,
#   'name': 'Y6',
#   'link': 'https://siuyeo.ng/MwcXY',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Loppy',
#   'link': 'https://siuyeo.ng/WwcSk',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Tina',
#   'link': 'https://siuyeo.ng/uwcWT',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Hank',
#   'link': 'https://siuyeo.ng/1wcxc',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Linda',
#   'link': 'https://siuyeo.ng/0wcfG',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '金多寶',
#   'link': 'https://siuyeo.ng/7wcwo',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': '阿雄',
#   'link': 'https://siuyeo.ng/JwxNz',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Jeffrey',
#   'link': 'https://siuyeo.ng/KwxJF',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Snake',
#   'gender': None,
#   'name': 'Z39',
#   'link': 'https://siuyeo.ng/qwxOq',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Nacho',
#   'link': 'https://siuyeo.ng/NwxEI',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Dino',
#   'link': 'https://siuyeo.ng/Jwxxd',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Roxy',
#   'link': 'https://siuyeo.ng/DwxsI',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Etta',
#   'link': 'https://siuyeo.ng/cwxed',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Diana',
#   'link': 'https://siuyeo.ng/8wz4T',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Jerry',
#   'link': 'https://siuyeo.ng/Iwz2O',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '曼曼',
#   'link': 'https://siuyeo.ng/zwzVw',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Snake',
#   'gender': None,
#   'name': '粉粉',
#   'link': 'https://siuyeo.ng/vwzSW',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Mugi',
#   'link': 'https://siuyeo.ng/0wzRZ',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Drake',
#   'link': 'https://siuyeo.ng/gwzxp',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Windie',
#   'link': 'https://siuyeo.ng/1wzgS',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Hera',
#   'link': 'https://siuyeo.ng/Owzwp',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '安安',
#   'link': 'https://siuyeo.ng/Uwl0x',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'June',
#   'link': 'https://siuyeo.ng/QwlCz',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': '糯米糍',
#   'link': 'https://siuyeo.ng/ewlSa',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Turtle',
#   'gender': None,
#   'name': '恐龍',
#   'link': 'https://siuyeo.ng/MwlYe',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Hoppin',
#   'link': 'https://siuyeo.ng/jwlmH',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Arlo',
#   'link': 'https://siuyeo.ng/fwllB',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': 'Siu Gut',
#   'link': 'https://siuyeo.ng/Twlsk',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Kyoho',
#   'link': 'https://siuyeo.ng/Swk6h',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '小唐菜',
#   'link': 'https://siuyeo.ng/Swk9D',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Jinnie',
#   'link': 'https://siuyeo.ng/jwkKG',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': '柴仔',
#   'link': 'https://siuyeo.ng/AwkFd',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': '蜥蜴',
#   'gender': None,
#   'name': 'AA04',
#   'link': 'https://siuyeo.ng/LwkUG',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Bokki',
#   'link': 'https://siuyeo.ng/Ywknl',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Sherpa',
#   'link': 'https://siuyeo.ng/nwkkN',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Jelly',
#   'link': 'https://siuyeo.ng/7wkup',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Kylo',
#   'link': 'https://siuyeo.ng/QwkqE',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '雪碧',
#   'link': 'https://siuyeo.ng/Wwj3P',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Beep Beep',
#   'link': 'https://siuyeo.ng/UwjZQ',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': '拉仔',
#   'link': 'https://siuyeo.ng/owjAv',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': '蜥蜴',
#   'gender': None,
#   'name': 'AA01',
#   'link': 'https://siuyeo.ng/cwjT1',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'F',
#   'name': 'Mercury',
#   'link': 'https://siuyeo.ng/UwjQd',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Quentin',
#   'link': 'https://siuyeo.ng/wwjfa',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Darlie',
#   'link': 'https://siuyeo.ng/bwjy8',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Billy',
#   'link': 'https://siuyeo.ng/Pwh72',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': 'Bonaqua',
#   'link': 'https://siuyeo.ng/SwhM1',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Jeep Jeep',
#   'link': 'https://siuyeo.ng/MwhLr',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '酷龍',
#   'link': 'https://siuyeo.ng/zwhDZ',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Turtle',
#   'gender': None,
#   'name': '小斑',
#   'link': 'https://siuyeo.ng/2whUS',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Rabit Society',
#   'type': 'Rabbit',
#   'gender': 'M',
#   'name': 'Zakka',
#   'link': 'https://siuyeo.ng/Bwhmf',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Hong Kong Dog Rescue',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Tansy',
#   'link': 'https://siuyeo.ng/kwhz8',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SPCA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Soda',
#   'link': 'https://siuyeo.ng/kwhpI',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'Paws United Charity',
#   'type': 'Dog',
#   'gender': 'M',
#   'name': 'Eggie',
#   'link': 'https://siuyeo.ng/Nwhwk',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKSCDA',
#   'type': 'Cat',
#   'gender': 'F',
#   'name': '呀嬌',
#   'link': 'https://siuyeo.ng/gwg48',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'SAA',
#   'type': 'Dog',
#   'gender': 'F',
#   'name': 'Jingle',
#   'link': 'https://siuyeo.ng/RwgVM',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKAAC',
#   'type': 'Cat',
#   'gender': 'M',
#   'name': '一言',
#   'link': 'https://siuyeo.ng/iwgJd',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  {'organization': 'HKHERP',
#   'type': 'Turtle',
#   'gender': None,
#   'name': 'PMKL003',
#   'link': 'https://siuyeo.ng/BwgAI',
#   'Unnamed: 5': None,
#   'Unnamed: 6': None,
#   'Unnamed: 7': None},
#  ...]

# %%
db = client['animalsdb']

# %%
db.list_collection_names()
# Out:
# ['animals']

# %%
# Create a new collection
collection = db.create_collection("animals")

# %%
collection.insert_many(list_of_dicts)
# Out:
# InsertManyResult([ObjectId('694d47ea48279e585de9a5fd'), ObjectId('694d47ea48279e585de9a5fe'), ObjectId('694d47ea48279e585de9a5ff'), ObjectId('694d47ea48279e585de9a600'), ObjectId('694d47ea48279e585de9a601'), ObjectId('694d47ea48279e585de9a602'), ObjectId('694d47ea48279e585de9a603'), ObjectId('694d47ea48279e585de9a604'), ObjectId('694d47ea48279e585de9a605'), ObjectId('694d47ea48279e585de9a606'), ObjectId('694d47ea48279e585de9a607'), ObjectId('694d47ea48279e585de9a608'), ObjectId('694d47ea48279e585de9a609'), ObjectId('694d47ea48279e585de9a60a'), ObjectId('694d47ea48279e585de9a60b'), ObjectId('694d47ea48279e585de9a60c'), ObjectId('694d47ea48279e585de9a60d'), ObjectId('694d47ea48279e585de9a60e'), ObjectId('694d47ea48279e585de9a60f'), ObjectId('694d47ea48279e585de9a610'), ObjectId('694d47ea48279e585de9a611'), ObjectId('694d47ea48279e585de9a612'), ObjectId('694d47ea48279e585de9a613'), ObjectId('694d47ea48279e585de9a614'), ObjectId('694d47ea48279e585de9a615'), ObjectId('694d47ea48279e585de9a616'), ObjectId('694d47ea48279e585de9a617'), ObjectId('694d47ea48279e585de9a618'), ObjectId('694d47ea48279e585de9a619'), ObjectId('694d47ea48279e585de9a61a'), ObjectId('694d47ea48279e585de9a61b'), ObjectId('694d47ea48279e585de9a61c'), ObjectId('694d47ea48279e585de9a61d'), ObjectId('694d47ea48279e585de9a61e'), ObjectId('694d47ea48279e585de9a61f'), ObjectId('694d47ea48279e585de9a620'), ObjectId('694d47ea48279e585de9a621'), ObjectId('694d47ea48279e585de9a622'), ObjectId('694d47ea48279e585de9a623'), ObjectId('694d47ea48279e585de9a624'), ObjectId('694d47ea48279e585de9a625'), ObjectId('694d47ea48279e585de9a626'), ObjectId('694d47ea48279e585de9a627'), ObjectId('694d47ea48279e585de9a628'), ObjectId('694d47ea48279e585de9a629'), ObjectId('694d47ea48279e585de9a62a'), ObjectId('694d47ea48279e585de9a62b'), ObjectId('694d47ea48279e585de9a62c'), ObjectId('694d47ea48279e585de9a62d'), ObjectId('694d47ea48279e585de9a62e'), ObjectId('694d47ea48279e585de9a62f'), ObjectId('694d47ea48279e585de9a630'), ObjectId('694d47ea48279e585de9a631'), ObjectId('694d47ea48279e585de9a632'), ObjectId('694d47ea48279e585de9a633'), ObjectId('694d47ea48279e585de9a634'), ObjectId('694d47ea48279e585de9a635'), ObjectId('694d47ea48279e585de9a636'), ObjectId('694d47ea48279e585de9a637'), ObjectId('694d47ea48279e585de9a638'), ObjectId('694d47ea48279e585de9a639'), ObjectId('694d47ea48279e585de9a63a'), ObjectId('694d47ea48279e585de9a63b'), ObjectId('694d47ea48279e585de9a63c'), ObjectId('694d47ea48279e585de9a63d'), ObjectId('694d47ea48279e585de9a63e'), ObjectId('694d47ea48279e585de9a63f'), ObjectId('694d47ea48279e585de9a640'), ObjectId('694d47ea48279e585de9a641'), ObjectId('694d47ea48279e585de9a642'), ObjectId('694d47ea48279e585de9a643'), ObjectId('694d47ea48279e585de9a644'), ObjectId('694d47ea48279e585de9a645'), ObjectId('694d47ea48279e585de9a646'), ObjectId('694d47ea48279e585de9a647'), ObjectId('694d47ea48279e585de9a648'), ObjectId('694d47ea48279e585de9a649'), ObjectId('694d47ea48279e585de9a64a'), ObjectId('694d47ea48279e585de9a64b'), ObjectId('694d47ea48279e585de9a64c'), ObjectId('694d47ea48279e585de9a64d'), ObjectId('694d47ea48279e585de9a64e'), ObjectId('694d47ea48279e585de9a64f'), ObjectId('694d47ea48279e585de9a650'), ObjectId('694d47ea48279e585de9a651'), ObjectId('694d47ea48279e585de9a652'), ObjectId('694d47ea48279e585de9a653'), ObjectId('694d47ea48279e585de9a654'), ObjectId('694d47ea48279e585de9a655'), ObjectId('694d47ea48279e585de9a656'), ObjectId('694d47ea48279e585de9a657'), ObjectId('694d47ea48279e585de9a658'), ObjectId('694d47ea48279e585de9a659'), ObjectId('694d47ea48279e585de9a65a'), ObjectId('694d47ea48279e585de9a65b'), ObjectId('694d47ea48279e585de9a65c'), ObjectId('694d47ea48279e585de9a65d'), ObjectId('694d47ea48279e585de9a65e'), ObjectId('694d47ea48279e585de9a65f'), ObjectId('694d47ea48279e585de9a660'), ObjectId('694d47ea48279e585de9a661'), ObjectId('694d47ea48279e585de9a662'), ObjectId('694d47ea48279e585de9a663'), ObjectId('694d47ea48279e585de9a664'), ObjectId('694d47ea48279e585de9 ...

# %%
collection.count_documents({})
# Out:
# 2071
